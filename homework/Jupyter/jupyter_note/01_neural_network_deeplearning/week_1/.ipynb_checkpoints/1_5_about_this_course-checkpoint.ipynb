# %% [markdown]
# # Coursera | Andrew Ng (01-week-1-1.5&1.6)—About this Course & Course Resources
#
#  该系列仅在原课程基础上部分知识点添加个人学习笔记，或相关推导补充等。如有错误，还请批评指教。在学习了 Andrew Ng 课程的基础上，为了更方便的查阅复习，将其整理成文字。因本人一直在学习英语，所以该系列以英文为主，同时也建议读者以英文为主，中文辅助，以便后期进阶时，为学习相关领域的学术论文做铺垫。- ZJ
#
# >[Coursera 课程](https://www.coursera.org/specializations/deep-learning) |[deeplearning.ai](https://www.deeplearning.ai/) |[网易云课堂](https://mooc.study.163.com/smartSpec/detail/1001319001.htm)
#
# ---
#    转载请注明作者和出处：微信公众号-「SelfImprovementLab」
#
#    [知乎](https://zhuanlan.zhihu.com/c_147249273)：https://zhuanlan.zhihu.com/c_147249273
#
#    [CSDN]()：
#
#    [简书]()：
#
# ---
# (字幕来源：网易云课堂)
#
# 关于这门课 & 课程资源
#
# So you're just about to reach the end of the first week
#
#
# ，学习进度来到了这个“微专业”第一门课，第一周的最后
#
#
# ,of material on the first course in this specialization.
#
# ，快速地介绍一下
# ,Let me give you a quick sense of
#
# ，下一周将要学习什么内容
# ,what you'll learn in the next few weeks as well.
#
# ，在第一个视频里 我已经说过
# ,As I said in the first video,
#
# ，本“微专业”一共有五门课
# ,this specialization comprises five courses.
#
# ，目前是第一门课
# ,And right now, we're in the first of these five courses
#
# ，在这门课中 将教会你最重要的基础知识
# ,which teach you the most important foundations,
#
# ，深度学习最重要的基础
# ,really the most important building blocks of deep learning.
#
# ，第一门课的结尾
# ,So by the end of this first course,
#
# ，你将掌握 如何建立并运用一个深度神经网络
# ,you know how to build and get to work a deep neural network.
#
# ，下面是第一门课的一些细节
# ,So here the details of what is in this first course.
#
# ，这门课有四个星期的学习材料
# ,This course is four weeks of material.
#
# ，目前你就要完成第一周的学习了
# ,And you're just coming up to the end of the first week
#
# ，学完了深度学习的入门介绍
# ,when you saw an introduction to deep learning.
#
# ，在每一周的结尾
# ,At the end of each week,
#
# ，都会有十道多选题
# ,there are also be 10 multiple-choice questions that
#
# ，可以用来检验自己对材料的理解
# ,you can use to double check your understanding of the material.
#
# ，当你看完这个视频的时候
# ,So when you're done watching this video,
#
# ，希望你能看看这些问题
# ,I hope you're going to take a look at those questions.
#
# ，在第二周 你会学习到
# ,In the second week, you then learn about
#
# ，神经网络的编程基础
# ,the Basics of Neural Network Programming.
#
# ，了解神经网络中
# ,You'll learn the structure of what we call
#
# ，“正向传播”和“反向传播”的结构
# ,the forward propagation and the back propagation
#
# ，还有算法的过程
# ,steps of the algorithm
#
# ，以及如何高效实现神经网络
# ,and how to implement neural networks efficiently.
#
# ，从第二周开始
# ,Starting from the second week,
#
# ，你也会开始做一些编程练习
# ,you also get to do a programming exercise
#
# ，练习学到的知识
# ,that lets you practice the material you've just learned,
#
# ，自己实现算法 亲自调试到完美运行
# ,implement the algorithms yourself and see it work for yourself.
#
# ，当我学习算法的时候 那让我很过瘾
# ,I find it really satisfying when I learn about algorithm
#
# ，通过代码编程 亲自看到它完美运行
# ,and they get it coded up and I see it worked for myself.
#
# ，我希望你们也喜欢
# ,So I hope you enjoy that too.
#
# ，在学习了神经网络编程的框架之后 在第三周
# ,Having learned the framework for neural network programming in the third week,
#
# ，你会编写单隐层神经网络
# ,you code up a single hidden layer neural network. All right.
#
# ，你需要学习所有必需的关键概念
# ,So you learn about all the key concepts needed to implement
#
# ，才能实现神经网络
# ,and get to work in neural network.
#
# ，最后在第四周
# ,And then finally in week four,
#
# ，你将建立了一个多层的深层神经网络
# ,you build a deep neural network and neural network with many layers.
#
# ，让它为你服务
# ,and see it worked for yourself.
#
# ，恭喜你完成了这段视频
# ,So, congratulations on finishing the videos after this one.
#
# ，我希望你现在对深度学习
# ,I hope that you now have a good high-level sense
#
# ，有一个高层次的理解
# ,of what's happening in deep learning.
#
# ，也许有些人会想
# ,And perhaps some of you are also assigned to,
#
# ，自己想到了
# ,has some ideas of where you might want to
#
# ，哪里可以应用深度学习
# ,apply deep learning yourself.
#
# ，我希望看完这段视频后
# ,So, I hope that after this video,
#
# ，你会去看那10个多项选择题
# ,you go on to take a look at the 10 multiple choice questions
#
# ，它们就在课程网站上
# ,that follow this video on the course website
#
# ，有10个多项选择题
# ,and just use the 10 multiple choice questions
#
# ，来检查你的理解
# ,to check your understanding.
#
# ，不用复习  第一次做不知道所有答案
# ,And don't review, you don't get all the answers right the first time,
#
# ，你可以多做几次 直到你把都做对了为止
# ,you can try again and again until you get them all right.
#
# ，我觉得这些问题很有用
# ,I found them useful to make sure
#
# ，能保证我理解了所有概念
# ,that I'm understanding all the concepts,
#
# ，我希望你也可以做到
# ,I hope you're that way too.
#
# ，说完了 再次祝贺你看到了这里
# ,So with that, congrats again for getting up to here
#
# ，期待在第二周的视频中 也看到你
# ,and I look forward to seeing you in the week two videos.
#
# 1.6
#
# ,I hope you enjoyed this course
#
#
# 希望你能够喜欢这门课程
#
# ，为了帮助你完成课程
# ,and to help you complete it
#
# ，我想要确保
# ,I want to make sure that
#
# ，你知道有下面这些课程材料
# ,there are a few course resources that you know about
#
# ，首先 如果你有任何疑问
# ,first if you have any questions
#
# ，想和这个课程的其它同学讨论
# ,or you want to discuss anything with the classmates
#
# ，想和包括我在内的教学人员讨论
# ,or the teaching staff including me
#
# ，或者想要归档一个错误报告
# ,or if you want to file a bug report
#
# ，论坛是去做这些事情最好的地方
# ,the best place to do that is the discussion forum
#
# 我和其他教学人员 会定期关注论坛
# ,the teaching staff and I will be monitoring that regularly
#
# 这也是一个
# ,and this is also a good place for you
#
# 从与你一同学习本课程的同学那 获取答案的好地方
# ,to get answers to your questions from your classmates
#
# 如果你想要回答同学们的问题
# ,or if you wish try to answer your classmates' questions
#
# 可以从课程首页 来到课程的论坛
# ,to get to the discussion forum from this course home page
#
# 如果你看到左侧的这个菜单栏
# ,if you look at this menu bar on the left
#
# 你的可能会看起来和我的有些不一样
# ,you also might look a bit different than mine
#
# 但都会有这个论坛模块
# ,but they'll do this discussion forum tab
#
# 当你点击它的时候
# ,which gives you click on
#
# 就会打开课程论坛
# ,gives you to the discussion forum
#
# 在论坛上提问 是问问题的最好方法
# ,the best way to ask questions is on the discussion forum
#
# 出于某些原因 你可能想直接联系我们
# ,but it for some reason you need to contact us directly
#
# 或是想让我们知道一些问题
# ,or let us know about some problem
#
# 尽管把邮件发送到这个邮箱地址
# ,feel free also to email us at this email address
#
# 我保证 我们会阅读每一个邮件
# ,I promise we will read every email
#
# 我们会尽力去解决经常出现的问题
# ,and we'll try to address commonly occurring issues
#
# 由于电子邮件的数量很多
# ,although depending on the email volume
#
# 我不能保证
# ,I can't guarantee that we'll be able
#
# 我们能够迅速回复每一封邮件
# ,to reply promptly to every email
#
# 但是我们会阅读你发送的每一封邮件
# ,but we will read every email that you send
#
# 另外 有些其它公司
# ,next I know that there are other companies
#
# 想要给大批的职员
# ,that wish to train maybe large numbers
#
# 培训深度学习的话
# ,of employees with deep learning
#
# 如果你在公司是负责培训工作
# ,if you're responsible for employee training in your company
#
# 想深度学习专家来培训
# ,and would like to train a hundred or more employees
#
# 上百或者更多的雇员
# ,with deep learning expertise
#
# 尽管通过这个电子邮箱联系我们
# ,please feel free to get in touch at this email
#
# 我们看看能否帮到你
# ,and we'll see if we can help you
#
# 我们在开发大学课程
# ,we're just in the early phases
#
# 但处于早期的阶段
# ,of developing the university academic program
#
# 如果你是大学领导
# ,but if you're a university instructor
#
# 或者管理人员
# ,or a university administrator
#
# 想在学校提供一门深度学习课程
# ,interested in offering a deep learning course at your university
#
# 请尽管通过这个邮箱地址联系我们
# ,please feel free to contact us at this email address
#
# 我会提供更多的资源 来完成这门课程
# ,though I hope that gives you more resources to complete the course
#
# 也许我会在论坛见到你噢
# ,maybe I'll see some of you in the discussion forums
#
# 祝你好运
# ,and best of luck
#
#
# ---
#
# **PS: 欢迎扫码关注公众号：「SelfImprovementLab」！专注「深度学习」，「机器学习」，「人工智能」。以及 「早起」，「阅读」，「运动」，「英语 」「其他」不定期建群 打卡互助活动。**
#
# <img src="http://upload-images.jianshu.io/upload_images/1157146-cab5ba89dfeeec4b.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240">
